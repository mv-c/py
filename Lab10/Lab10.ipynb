# %%
import pandas
# load the csv
data = pandas.read_csv("nba.csv")
# show first 5 column
data.head()
# Out:
#       Name   Team  Number Position   Age Height  Weight College     Salary
# 0   Sachin  Bosco     0.0       PG  25.0    6-2   180.0   Texas  7730337.0
# 1   Ganesh  Bosco    99.0       SF  25.0    6-6   235.0    Marq  6796117.0
# 2  Vineeth  Bosco    30.0       SG  27.0    6-5   205.0   Bosco        NaN
# 3    Subin  Bosco    28.0       SG  22.0    5-5   185.0  George  1148640.0
# 4    GObra  Bosco     8.0       PF  29.0   9-10   231.0     NaN   500000.0

# %%
#To perform data visualization using Seaborn:
# import module
import seaborn as sns
import pandas
# read the csv data
data = pandas.read_csv("nba.csv")
# plot
sns.lineplot(data['Age'],data['Weight'], hue =data["Position"])
# Out:
# C:\Users\sachi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Weight'>

# %%
# import module
import seaborn
import pandas
# load csv
data = pandas.read_csv("nba.csv")
# plotting
seaborn.scatterplot(data['Age'],data['Weight'])
# Out:
# C:\Users\sachi\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='Weight'>
